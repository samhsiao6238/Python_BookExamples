# %%
"""
全天候資產配置
"""


# 載入函數工具檔
from Data import getDataYF
from FinancialMetrics import PortfolioRiskReturnRatio

# 定義資產配置商品、比例
asset_allocation = {
    "VTI": 0.3,  # 股票 30%
    "TLT": 0.40,  # 長期債券 40%
    "IEF": 0.15,  # 中期債券 15%
    "DBC": 0.075,  # 原物料 7.5%
    "GLD": 0.075,  # 貴金屬 7.5%
}


# 計算投資組合風險報酬
PortfolioRiskReturnRatio(getDataYF, asset_allocation, "adj close", 500000)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                  VTI       TLT       IEF       DBC       GLD
# Date
# 2006-02-07  0.990263  0.995277  0.998794  0.971074  0.962623
# 2006-02-08  1.007195  0.997682  0.999396  0.995745  1.004213
# 2006-02-09  0.998096  1.004536  1.000967  1.009402  1.024622
# 2006-02-10  1.002067  0.994493  0.997103  0.981795  0.975258
# 2006-02-13  0.995477  1.000111  1.000000  0.984476  0.980471
# ...              ...       ...       ...       ...       ...
# 2024-04-01  0.999231  0.981359  0.990952  1.004789  1.010208
# 2024-04-02  0.990758  0.994489  0.997862  1.009099  1.014772
# 2024-04-03  1.001555  0.999783  1.001179  1.012022  1.008772
# 2024-04-04  0.988009  1.007172  1.003425  1.002546  0.994265
# 2024-04-05  1.010094  0.986081  0.993387  1.005078  1.017114
#
# [4571 rows x 5 columns]
# 商品:VTI 權重:0.3
# 商品:TLT 權重:0.4
# 商品:IEF 權重:0.15
# 商品:DBC 權重:0.075
# 商品:GLD 權重:0.075
# 投資組合年化報酬:0.05381038297109332
# 投資組合風險:2.717422610785288e-05
